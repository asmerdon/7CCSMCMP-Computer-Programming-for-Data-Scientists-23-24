# %% [markdown]
# # Activity 3

# %% [markdown]
# ## 3.1 Sub-activity: Loading and pre-processing of text data

# %% [markdown]
# ### Task 1:

# %%
# To figure out how to get the Wikidata and Wikipedia APIs working I used code from these sources:
# https://www.jcchouinard.com/wikidata-api-python/
# https://www.wikidata.org/wiki/Wikidata:REST_API
# https://agg-shashank.medium.com/an-introduction-to-using-wikidata-apis-a678ee6d2968
# https://www.wikidata.org/wiki/Wikidata:REST_API
# https://wikipedia-api.readthedocs.io/en/latest/wikipediaapi/api.html

import requests

def get_turing_award_recipients():
    wikidata_api_url = "https://www.wikidata.org/w/api.php" # base url
    params = {
        'action': 'query',
        'format': 'json',
        'list': 'backlinks',
        'bltitle': 'Q185667',  # wikidata item for turing award
        'blnamespace': 0,
        'blfilterredir': 'nonredirects',
        'bllimit': 500  # limit
    }

    response = requests.get(url=wikidata_api_url, params=params)
    backlinks = response.json()['query']['backlinks'] # ids for recipients are found in 'backlinks' of response

    if not backlinks:
        print("No backlinks found.")
        return

    recipients = [] # declare empty list for recipients
    for backlink in backlinks: # get each recipient
        recipient_id = backlink['title']
        recipients.append(recipient_id) #also gets ids of other links in table
    return recipients

turing_award_recipients = get_turing_award_recipients() # get recipients
for recipient_id in turing_award_recipients:
   print(f"Recipient ID: {recipient_id}")
# Out:
# Recipient ID: Q80
# Recipient ID: Q8556
# Recipient ID: Q9602
# Recipient ID: Q11609
# Recipient ID: Q17457
# Recipient ID: Q45575
# Recipient ID: Q49823
# Recipient ID: Q62843
# Recipient ID: Q62857
# Recipient ID: Q62861
# Recipient ID: Q62866
# Recipient ID: Q62870
# Recipient ID: Q62874
# Recipient ID: Q62877
# Recipient ID: Q62888
# Recipient ID: Q62894
# Recipient ID: Q62898
# Recipient ID: Q92596
# Recipient ID: Q92602
# Recipient ID: Q92604
# Recipient ID: Q92606
# Recipient ID: Q92609
# Recipient ID: Q92612
# Recipient ID: Q92613
# Recipient ID: Q92614
# Recipient ID: Q92618
# Recipient ID: Q92619
# Recipient ID: Q92625
# Recipient ID: Q92626
# Recipient ID: Q92628
# Recipient ID: Q92629
# Recipient ID: Q92632
# Recipient ID: Q92638
# Recipient ID: Q92641
# Recipient ID: Q92643
# Recipient ID: Q92644
# Recipient ID: Q92649
# Recipient ID: Q92670
# Recipient ID: Q92739
# Recipient ID: Q92742
# Recipient ID: Q92743
# Recipient ID: Q92744
# Recipient ID: Q92745
# Recipient ID: Q92746
# Recipient ID: Q92758
# Recipient ID: Q92766
# Recipient ID: Q92781
# Recipient ID: Q92782
# Recipient ID: Q92794
# Recipient ID: Q92819
# Recipient ID: Q92820
# Recipient ID: Q92821
# Recipient ID: Q92822
# Recipient ID: Q92823
# Recipient ID: Q92824
# Recipient ID: Q92828
# Recipient ID: Q92851
# Recipient ID: Q92854
# Recipient ID: Q92894
# Recipient ID: Q93080
# Recipient ID: Q93154
# Recipient ID: Q93161
# Recipient ID: Q127992
# Recipient ID: Q181529
# Recipient ID: Q204815
# Recipient ID: Q320624
# Recipient ID: Q357965
# Recipient ID: Q439245
# Recipient ID: Q462089
# Recipient ID: Q476466
# Recipient ID: Q578036
# Recipient ID: Q918650
# Recipient ID: Q1107006
# Recipient ID: Q3571662
# Recipient ID: Q3572699
# Recipient ID: Q6600724
# Recipient ID: Q7143512
# Recipient ID: Q8091443
# Recipient ID: Q8317928
# Recipient ID: Q9241105
# Recipient ID: Q16080922
# Recipient ID: Q56067342

# %% [markdown]
# ### Task 2

# %%
def get_wikipedia_content(wikidata_id):
    wikidata_api_url = "https://www.wikidata.org/w/api.php" # base url
    params = { # parameters
        'action': 'wbgetentities',
        'format': 'json', # returns json format
        'ids': wikidata_id, #input
        'props': 'sitelinks' #
    }
    response = requests.get(url=wikidata_api_url, params=params) # fetch request
    wikidata_data = response.json() # convert to json
    sitelinks = wikidata_data['entities'][wikidata_id]['sitelinks']

    if 'enwiki' not in sitelinks: # make sure it's english wikipedia
        return None

    wikipedia_title = sitelinks['enwiki']['title'] # use the wikipedia api to get wikipedia page content
    wikipedia_api_url = "https://en.wikipedia.org/w/api.php"
    params = { # parameters
        'action': 'query',
        'format': 'json', # returns json format
        'titles': wikipedia_title,
        'prop': 'revisions',
        'rvprop': 'content'
    }
    response = requests.get(url=wikipedia_api_url, params=params) # call
    wikipedia_data = response.json()
    pages = wikipedia_data['query']['pages']
    page_id = next(iter(pages)) # get page content
    content = pages[page_id]['revisions'][0]['*'] # revision is a version of an article (with [0][*] being all the content of the most recent)
    return content # returns page

# %% [markdown]
# ### Task 3:

# %%
# My solution returns the intro, but it's a very short one. My attempt tried to use BeautifulSoup to parse the information, however I could not find the
# HTML to get the intro from the returned Wikipedia article. The intro length impacts how well the NLP later on works. Regex is instead used to get the intros.

# This task can take a while to run.

import requests
from bs4 import BeautifulSoup
import re

def get_wikipedia_intro(wikipedia_content):
    #soup = BeautifulSoup(wikipedia_content, 'html.parser') #parse the data with beautifulsoup
    short_description_match = re.search(r'\{\{short description\|(.+?)\}\}', wikipedia_content) # find the content within double curly braces and containing "short description". regex
    if short_description_match: # extract the short description if the pattern is found
        short_description = short_description_match.group(1) # assign matched text 
    else:
        short_description = None
        
    return short_description

def get_wikidata_info(recipient_id): # function takes in wikidata entity value (of each award winner)
    wikidata_api_url = "https://www.wikidata.org/w/api.php" # base url
    params = {
        'action': 'wbgetentities',
        'format': 'json',
        'ids': recipient_id,
        'props': 'claims|labels' # claims are information about a person, labels are metadata info (to get english content)
    }

    response = requests.get(url=wikidata_api_url, params=params) # call wikidata api
    entity_info = response.json().get('entities', {}).get(recipient_id, {}) # parses response and puts it into a dictionary (with entities as a key).
    return entity_info # return

def get_entity_name(entity_id): # function that gets the name of the wikidata entity from english wikipedia
    entity_info = get_wikidata_info(entity_id)
    return entity_info.get('labels', {}).get('en', {}).get('value', None)

def get_claim_value(claims, property_id): # again, a claim is information about a person. this function takes in a claims for a person, and IDs representing the specific info wanted
    claim_list = claims.get(property_id, [])
    if claim_list:
        mainsnak = claim_list[0].get('mainsnak', {}) # mainsnak contains the data value
        datavalue = mainsnak.get('datavalue', {}) # part of the mainsnak that holds the valye
        value = datavalue.get('value') # the value itself
        if value and 'id' in value: # if the value has an id, get that, otherwise return the value itself
            return get_entity_name(value['id'])
        return value
    return None

award_winners = [] # declare empty list of award winners

for recipient_id in turing_award_recipients: #iterate through list of wikidata entities of turing award winners
    wikipedia_content = get_wikipedia_content(recipient_id) # get wikipedia page
    if wikipedia_content:
        wikipedia_intro = get_wikipedia_intro(wikipedia_content) # get introduction from wikipedia
        recipient_info = get_wikidata_info(recipient_id) # get wikidata info
        award_winner = { # create dictionary for award winner
            'name': get_entity_name(recipient_id), # call function to get recipient name
            'intro': wikipedia_intro,
            'gender': get_claim_value(recipient_info.get('claims', {}), 'P21'), # call function to get info about person. each p value corresponds to what's needed
            'birth_date': get_claim_value(recipient_info.get('claims', {}), 'P569'), # birth date
            'birth_place': get_claim_value(recipient_info.get('claims', {}), 'P19'), # birth place
            'employer': get_claim_value(recipient_info.get('claims', {}), 'P108'), # employer
            'educated_at': get_claim_value(recipient_info.get('claims', {}), 'P69') # education/uni
        }
        award_winners.append(award_winner) #add the award winner's information to the list

for winner_info in award_winners: # print award winners
    print("Award Winner Information:")
    print(winner_info)
    print("\n")
# Out:
# Award Winner Information:
# {'name': 'Tim Berners-Lee', 'intro': 'English computer scientist, inventor of the World Wide Web (born 1955)', 'gender': 'male', 'birth_date': {'time': '+1955-06-08T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'London', 'employer': 'World Wide Web Consortium', 'educated_at': "The Queen's College"}
#
#
# Award Winner Information:
# {'name': 'Edsger W. Dijkstra', 'intro': 'Dutch computer scientist (1930–2002)', 'gender': 'male', 'birth_date': {'time': '+1930-05-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Rotterdam', 'employer': 'University of Texas at Austin', 'educated_at': 'Leiden University'}
#
#
# Award Winner Information:
# {'name': 'Frances E. Allen', 'intro': None, 'gender': 'female', 'birth_date': {'time': '+1932-08-04T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Peru', 'employer': 'IBM', 'educated_at': 'State University of New York at Albany'}
#
#
# Award Winner Information:
# {'name': 'Shafrira Goldwasser', 'intro': 'Israeli American computer scientist', 'gender': 'female', 'birth_date': {'time': '+1958-11-14T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'Carnegie Mellon University'}
#
#
# Award Winner Information:
# {'name': 'Donald Knuth', 'intro': 'American computer scientist and mathematician (born 1938)', 'gender': 'male', 'birth_date': {'time': '+1938-01-10T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Milwaukee', 'employer': 'Stanford University', 'educated_at': 'Case Western Reserve University'}
#
#
# Award Winner Information:
# {'name': 'Dennis M. Ritchie', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1941-09-09T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Bronxville', 'employer': 'Bell Labs', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Dana Scott', 'intro': 'American logician (born 1932)', 'gender': 'male', 'birth_date': {'time': '+1932-10-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Berkeley', 'employer': 'University of California, Berkeley', 'educated_at': 'Princeton University'}
#
#
# Award Winner Information:
# {'name': 'Bob Kahn', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1938-12-23T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'City College of New York'}
#
#
# Award Winner Information:
# {'name': 'Maurice Wilkes', 'intro': 'British computer scientist (1913–2010)', 'gender': 'male', 'birth_date': {'time': '+1913-06-26T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Dudley', 'employer': 'Digital Equipment Corporation', 'educated_at': "St John's College"}
#
#
# Award Winner Information:
# {'name': 'Alan Perlis', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1922-04-01T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Pittsburgh', 'employer': 'Yale University', 'educated_at': 'Carnegie Mellon University'}
#
#
# Award Winner Information:
# {'name': 'Ivan Sutherland', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1938-05-16T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Hastings', 'employer': 'Harvard University', 'educated_at': 'Massachusetts Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Stephen Cook', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1939-12-14T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Buffalo', 'employer': 'University of Toronto', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'John Edward Hopcroft', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1939-10-07T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Seattle', 'employer': 'Cornell University', 'educated_at': 'Stanford University'}
#
#
# Award Winner Information:
# {'name': 'James H. Wilkinson', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1919-09-27T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Strood', 'employer': 'National Physical Laboratory', 'educated_at': 'Trinity College'}
#
#
# Award Winner Information:
# {'name': 'Andrew Yao', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1946-12-24T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Shanghai', 'employer': 'Princeton University', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Charles Bachman', 'intro': 'American computer scientist', 'gender': 'male', 'birth_date': {'time': '+1924-12-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Manhattan', 'employer': 'Dow Chemical Company', 'educated_at': 'Michigan State University'}
#
#
# Award Winner Information:
# {'name': 'Alfred Aho', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1941-08-09T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Timmins', 'employer': 'Columbia University', 'educated_at': 'University of Toronto'}
#
#
# Award Winner Information:
# {'name': 'Edgar F. Codd', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1923-08-19T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Isle of Portland', 'employer': 'IBM', 'educated_at': 'Exeter College'}
#
#
# Award Winner Information:
# {'name': 'Tony Hoare', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1934-01-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Colombo', 'employer': 'Microsoft', 'educated_at': 'Moscow State University'}
#
#
# Award Winner Information:
# {'name': 'Niklaus Wirth', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1934-02-15T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Winterthur', 'employer': 'PARC', 'educated_at': 'ETH Zurich'}
#
#
# Award Winner Information:
# {'name': 'Jim Gray', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1944-01-12T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'San Francisco', 'employer': 'Microsoft', 'educated_at': 'University of California, Berkeley'}
#
#
# Award Winner Information:
# {'name': 'Fred Brooks', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1931-04-19T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Durham', 'employer': 'IBM', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Richard M. Karp', 'intro': 'American mathematician', 'gender': 'male', 'birth_date': {'time': '+1935-01-03T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Boston', 'employer': 'University of California, Berkeley', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Leslie Lamport', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1941-02-07T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'MITRE Corporation', 'educated_at': 'Massachusetts Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Douglas Engelbart', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1925-01-30T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Portland', 'employer': 'University of California, Berkeley', 'educated_at': 'University of California, Berkeley'}
#
#
# Award Winner Information:
# {'name': 'Peter Naur', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1928-10-25T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Frederiksberg', 'employer': 'University of Copenhagen', 'educated_at': 'University of Copenhagen'}
#
#
# Award Winner Information:
# {'name': 'Richard Hamming', 'intro': 'American mathematician and information theorist', 'gender': 'male', 'birth_date': {'time': '+1915-02-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Chicago', 'employer': 'Bell Labs', 'educated_at': 'University of Chicago'}
#
#
# Award Winner Information:
# {'name': 'Fernando J. Corbató', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1926-07-01T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Oakland', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'California Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Manuel Blum', 'intro': 'Venezuelan computer scientist|bot=PearBOT 5', 'gender': 'male', 'birth_date': {'time': '+1938-04-26T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Caracas', 'employer': 'University of California, Berkeley', 'educated_at': 'Massachusetts Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Juris Hartmanis', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1928-07-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Riga', 'employer': 'Cornell University', 'educated_at': 'California Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Kenneth E. Iverson', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1920-12-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Camrose', 'employer': 'IBM', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'John Cocke', 'intro': 'American computer scientist and mathematician', 'gender': 'male', 'birth_date': {'time': '+1925-05-30T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Charlotte', 'employer': 'IBM', 'educated_at': 'Duke University'}
#
#
# Award Winner Information:
# {'name': 'Robert Tarjan', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1948-04-30T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Pomona', 'employer': 'Princeton University', 'educated_at': 'California Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Robert W. Floyd', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1936-06-08T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Carnegie Mellon University', 'educated_at': 'University of Chicago'}
#
#
# Award Winner Information:
# {'name': 'Robin Milner', 'intro': 'British computer scientist (1934–2010)', 'gender': 'male', 'birth_date': {'time': '+1934-01-13T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Plymouth', 'employer': 'City, University of London', 'educated_at': 'Eton College'}
#
#
# Award Winner Information:
# {'name': 'Butler Lampson', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1943-12-23T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Washington, D.C.', 'employer': 'PARC', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Amir Pnueli', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1941-04-22T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Nahalal', 'employer': 'New York University', 'educated_at': 'Technion – Israel Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Jack Dongarra', 'intro': 'American computer scientist (born 1950)', 'gender': 'male', 'birth_date': {'time': '+1950-07-18T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Chicago', 'employer': 'University of Manchester', 'educated_at': 'Illinois Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'John McCarthy', 'intro': 'American computer scientist and cognitive scientist', 'gender': 'male', 'birth_date': {'time': '+1927-09-04T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Boston', 'employer': 'Princeton University', 'educated_at': 'California Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Alan Kay', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1940-05-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Springfield', 'employer': 'University of California, Los Angeles', 'educated_at': 'University of Utah'}
#
#
# Award Winner Information:
# {'name': 'Vint Cerf', 'intro': 'American computer scientist (born 1943)', 'gender': 'male', 'birth_date': {'time': '+1943-06-23T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New Haven', 'employer': 'Google', 'educated_at': 'Stanford University'}
#
#
# Award Winner Information:
# {'name': 'Kristen Nygaard', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1926-08-27T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Oslo', 'employer': 'University of Oslo', 'educated_at': 'University of Oslo'}
#
#
# Award Winner Information:
# {'name': 'Ole-Johan Dahl', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1931-10-12T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Mandal Municipality', 'employer': 'University of Oslo', 'educated_at': 'University of Oslo'}
#
#
# Award Winner Information:
# {'name': 'John Backus', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1924-12-03T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Philadelphia', 'employer': 'IBM', 'educated_at': 'Columbia University'}
#
#
# Award Winner Information:
# {'name': 'Michael Stonebraker', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1943-10-11T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Milton', 'employer': 'University of California, Berkeley', 'educated_at': 'Princeton University'}
#
#
# Award Winner Information:
# {'name': 'Robert Metcalfe', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1946-04-07T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Brooklyn', 'employer': 'PARC', 'educated_at': 'MIT Sloan School of Management'}
#
#
# Award Winner Information:
# {'name': 'Iosif Sifakis', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1946-12-26T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Heraklion', 'employer': 'National Center for Scientific Research', 'educated_at': 'National Technical University of Athens'}
#
#
# Award Winner Information:
# {'name': 'William Kahan', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1933-06-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Toronto', 'employer': 'University of California, Berkeley', 'educated_at': 'University of Toronto'}
#
#
# Award Winner Information:
# {'name': 'Jeffrey David Ullman', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1942-11-22T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Stanford University', 'educated_at': 'Princeton University'}
#
#
# Award Winner Information:
# {'name': 'Edmund M. Clarke', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1945-07-27T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Newport News', 'employer': 'Duke University', 'educated_at': 'University of Virginia'}
#
#
# Award Winner Information:
# {'name': 'Raj Reddy', 'intro': 'Indian-American computer scientist (born 1937)', 'gender': 'male', 'birth_date': {'time': '+1937-06-13T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Katur', 'employer': 'Carnegie Mellon University', 'educated_at': 'Stanford University'}
#
#
# Award Winner Information:
# {'name': 'E. Allen Emerson', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1954-06-02T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Dallas', 'employer': 'University of Texas at Austin', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Richard E. Stearns', 'intro': 'American computer scientist', 'gender': 'male', 'birth_date': {'time': '+1936-07-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Caldwell', 'employer': 'State University of New York at Albany', 'educated_at': 'Princeton University'}
#
#
# Award Winner Information:
# {'name': 'Edward Feigenbaum', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1936-01-20T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Weehawken', 'employer': 'Stanford University', 'educated_at': 'Carnegie Mellon University'}
#
#
# Award Winner Information:
# {'name': 'Judea Pearl', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1936-09-04T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Tel Aviv', 'employer': 'University of California, Los Angeles', 'educated_at': 'Rutgers University'}
#
#
# Award Winner Information:
# {'name': 'Charles P. Thacker', 'intro': 'American computer scientist', 'gender': 'male', 'birth_date': {'time': '+1943-02-26T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Pasadena', 'employer': 'PARC', 'educated_at': 'University of California, Berkeley'}
#
#
# Award Winner Information:
# {'name': 'David A. Patterson', 'intro': 'American computer pioneer and academic (born 1947)', 'gender': 'male', 'birth_date': {'time': '+1947-11-16T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Evergreen Park', 'employer': 'University of California, Berkeley', 'educated_at': 'University of California, Los Angeles'}
#
#
# Award Winner Information:
# {'name': 'John L. Hennessy', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1952-09-22T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Huntington', 'employer': 'Stanford University', 'educated_at': 'Stony Brook University'}
#
#
# Award Winner Information:
# {'name': 'Geoffrey Hinton', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1947-12-06T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Wimbledon', 'employer': 'University of Toronto', 'educated_at': 'University of Edinburgh'}
#
#
# Award Winner Information:
# {'name': 'Silvio Micali', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1954-10-13T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Palermo', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'University of California, Berkeley'}
#
#
# Award Winner Information:
# {'name': 'Leslie Valiant', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1949-03-28T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Budapest', 'employer': 'Harvard University', 'educated_at': 'Imperial College London'}
#
#
# Award Winner Information:
# {'name': 'Edwin Catmull', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1945-03-31T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Parkersburg', 'employer': 'Applicon', 'educated_at': 'University of Utah'}
#
#
# Award Winner Information:
# {'name': 'Association for Computing Machinery', 'intro': None, 'gender': None, 'birth_date': None, 'birth_place': None, 'employer': None, 'educated_at': None}
#
#
# Award Winner Information:
# {'name': 'Herbert Simon', 'intro': 'American political scientist, economist, sociologist, and psychologist', 'gender': 'male', 'birth_date': {'time': '+1916-06-15T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Milwaukee', 'employer': 'Carnegie Mellon University', 'educated_at': 'University of Chicago'}
#
#
# Award Winner Information:
# {'name': 'Marvin Minsky', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1927-08-09T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'Harvard University'}
#
#
# Award Winner Information:
# {'name': 'Adi Shamir', 'intro': 'Israeli cryptographer (born 1952)', 'gender': 'male', 'birth_date': {'time': '+1952-07-06T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Tel Aviv', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'Tel Aviv University'}
#
#
# Award Winner Information:
# {'name': 'Michael O. Rabin', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1931-09-01T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Wrocław', 'employer': 'Harvard University', 'educated_at': 'Hebrew University of Jerusalem'}
#
#
# Award Winner Information:
# {'name': 'Allen Newell', 'intro': 'American cognitive scientist', 'gender': 'male', 'birth_date': {'time': '+1927-03-19T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'San Francisco', 'employer': 'Carnegie Mellon University', 'educated_at': 'Stanford University'}
#
#
# Award Winner Information:
# {'name': 'Whitfield Diffie', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1944-06-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'University of London', 'educated_at': 'Massachusetts Institute of Technology'}
#
#
# Award Winner Information:
# {'name': 'Martin Edward Hellman', 'intro': 'American cryptologist (born 1945)', 'gender': 'male', 'birth_date': {'time': '+1945-10-02T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New York City', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'New York University'}
#
#
# Award Winner Information:
# {'name': 'Ron Rivest', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1947-05-06T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Schenectady', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'Stanford University'}
#
#
# Award Winner Information:
# {'name': 'Leonard Adleman', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1945-12-31T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'California', 'employer': 'University of Southern California', 'educated_at': 'University of California Botanical Garden'}
#
#
# Award Winner Information:
# {'name': 'Ken Thompson', 'intro': 'American computer scientist, co-creator of the Unix operating system', 'gender': 'male', 'birth_date': {'time': '+1943-02-04T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'New Orleans', 'employer': 'Bell Labs', 'educated_at': 'University of California, Berkeley'}
#
#
# Award Winner Information:
# {'name': 'Yann LeCun', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1960-07-08T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Paris', 'employer': 'Meta Platforms', 'educated_at': 'ESIEE Paris'}
#
#
# Award Winner Information:
# {'name': 'Yoshua Bengio', 'intro': None, 'gender': 'male', 'birth_date': {'time': '+1964-03-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Paris', 'employer': 'University of Montreal', 'educated_at': 'McGill University'}
#
#
# Award Winner Information:
# {'name': 'Pat Hanrahan', 'intro': 'American computer graphics researcher', 'gender': 'male', 'birth_date': {'time': '+1955-05-00T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 10, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': None, 'employer': 'Stanford University', 'educated_at': 'University of Wisconsin–Madison'}
#
#
# Award Winner Information:
# {'name': 'Template:Turing Award laureates', 'intro': None, 'gender': None, 'birth_date': None, 'birth_place': None, 'employer': None, 'educated_at': None}
#
#
# Award Winner Information:
# {'name': 'Category:Turing Award laureates', 'intro': None, 'gender': None, 'birth_date': None, 'birth_place': None, 'employer': None, 'educated_at': None}
#
#
# Award Winner Information:
# {'name': 'Barbara Liskov', 'intro': 'American computer scientist', 'gender': 'female', 'birth_date': {'time': '+1939-11-07T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, 'birth_place': 'Los Angeles', 'employer': 'Massachusetts Institute of Technology', 'educated_at': 'Stanford University'}

# %% [markdown]
# ### Task 4:

# %%
names = [winner['name'] for winner in award_winners]# extract names from award_winners
sorted_names = sorted(names) # sort names in alphabetical order
for name in sorted_names: # print
    print(name)
# Out:
# Adi Shamir
# Alan Kay
# Alan Perlis
# Alfred Aho
# Allen Newell
# Amir Pnueli
# Andrew Yao
# Association for Computing Machinery
# Barbara Liskov
# Bob Kahn
# Butler Lampson
# Category:Turing Award laureates
# Charles Bachman
# Charles P. Thacker
# Dana Scott
# David A. Patterson
# Dennis M. Ritchie
# Donald Knuth
# Douglas Engelbart
# E. Allen Emerson
# Edgar F. Codd
# Edmund M. Clarke
# Edsger W. Dijkstra
# Edward Feigenbaum
# Edwin Catmull
# Fernando J. Corbató
# Frances E. Allen
# Fred Brooks
# Geoffrey Hinton
# Herbert Simon
# Iosif Sifakis
# Ivan Sutherland
# Jack Dongarra
# James H. Wilkinson
# Jeffrey David Ullman
# Jim Gray
# John Backus
# John Cocke
# John Edward Hopcroft
# John L. Hennessy
# John McCarthy
# Judea Pearl
# Juris Hartmanis
# Ken Thompson
# Kenneth E. Iverson
# Kristen Nygaard
# Leonard Adleman
# Leslie Lamport
# Leslie Valiant
# Manuel Blum
# Martin Edward Hellman
# Marvin Minsky
# Maurice Wilkes
# Michael O. Rabin
# Michael Stonebraker
# Niklaus Wirth
# Ole-Johan Dahl
# Pat Hanrahan
# Peter Naur
# Raj Reddy
# Richard E. Stearns
# Richard Hamming
# Richard M. Karp
# Robert Metcalfe
# Robert Tarjan
# Robert W. Floyd
# Robin Milner
# Ron Rivest
# Shafrira Goldwasser
# Silvio Micali
# Stephen Cook
# Template:Turing Award laureates
# Tim Berners-Lee
# Tony Hoare
# Vint Cerf
# Whitfield Diffie
# William Kahan
# Yann LeCun
# Yoshua Bengio

# %% [markdown]
# ### Task 5:

# %%
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import string
from collections import Counter

stopwords = set(stopwords.words('english')) # stop words

def count_words(text): # function to count the number of words in text
    return len(word_tokenize(str(text))) # word tokenize function from nltk

def count_sentences(text): # function to count sentences in a paragraph
    return len(sent_tokenize(str(text))) # sentance tokenize function from nltk

def count_paragraphs(text): # function to count number of paragraphs in a text
    return len(str(text).split('\n\n')) # split on new line

def get_top_words(text): # function to get top words
    words = word_tokenize(str(text)) #tokenize
    word_counts = Counter(words) # Counter iterates over words list 
    top_words = word_counts.most_common(10) # gets most comon words

    return top_words

def preprocess_text(text): # function to preprocess text
    words = word_tokenize(str(text)) # tokenize
    filtered_words = [ # remove stopwords and punctuation
        word.lower()
        for word in words
        if word.lower() not in stopwords and word.lower() not in string.punctuation # if not stopword or punctuation, include in filtered words list
    ]
    return filtered_words #return list

df = pd.DataFrame(award_winners) # convert to dataframe
df['count_words'] = df['intro'].apply(count_words) # add count_words column
df['count_sentences'] = df['intro'].apply(count_sentences) # add count_sentences column
df['count_paragraphs'] = df['intro'].apply(count_paragraphs) # add count_paragraph column
df['common_words'] = df['intro'].apply(get_top_words) # add common_words common (not preprocessed)
df['common_words_after_preprocessing'] = df['intro'].apply(preprocess_text) # add pre processed common words
display(df.head(10)) # display top 10
# Out:
#                   name                                              intro
# 0      Tim Berners-Lee  English computer scientist, inventor of the Wo...  \
# 1   Edsger W. Dijkstra               Dutch computer scientist (1930–2002)
# 2     Frances E. Allen                                               None
# 3  Shafrira Goldwasser                Israeli American computer scientist
# 4         Donald Knuth  American computer scientist and mathematician ...
# 5    Dennis M. Ritchie                                               None
# 6           Dana Scott                      American logician (born 1932)
# 7             Bob Kahn                                               None
# 8       Maurice Wilkes             British computer scientist (1913–2010)
# 9          Alan Perlis                                               None
#
#    gender                                         birth_date    birth_place
# 0    male  {'time': '+1955-06-08T00:00:00Z', 'timezone': ...         London  \
# 1    male  {'time': '+1930-05-11T00:00:00Z', 'timezone': ...      Rotterdam
# 2  female  {'time': '+1932-08-04T00:00:00Z', 'timezone': ...           Peru
# 3  female  {'time': '+1958-11-14T00:00:00Z', 'timezone': ...  New York City
# 4    male  {'time': '+1938-01-10T00:00:00Z', 'timezone': ...      Milwaukee
# 5    male  {'time': '+1941-09-09T00:00:00Z', 'timezone': ...     Bronxville
# 6    male  {'time': '+1932-10-11T00:00:00Z', 'timezone': ...       Berkeley
# 7    male  {'time': '+1938-12-23T00:00:00Z', 'timezone': ...  New York City
# 8    male  {'time': '+1913-06-26T00:00:00Z', 'timezone': ...         Dudley
# 9    male  {'time': '+1922-04-01T00:00:00Z', 'timezone': ...     Pittsburgh
#
#                                 employer
# 0              World Wide Web Consortium  \
# 1          University of Texas at Austin
# 2                                    IBM
# 3  Massachusetts Institute of Technology
# 4                    Stanford University
# 5                              Bell Labs
# 6     University of California, Berkeley
# 7  Massachusetts Institute of Technology
# 8          Digital Equipment Corporation
# 9                        Yale University
#
#                               educated_at  count_words  count_sentences
# 0                     The Queen's College           14                1  \
# 1                       Leiden University            6                1
# 2  State University of New York at Albany            1                1
# 3              Carnegie Mellon University            4                1
# 4         Case Western Reserve University            9                1
# 5                      Harvard University            1                1
# 6                    Princeton University            6                1
# 7                City College of New York            1                1
# 8                       St John's College            6                1
# 9              Carnegie Mellon University            1                1
#
#    count_paragraphs                                       common_words
# 0                 1  [(English, 1), (computer, 1), (scientist, 1), ...  \
# 1                 1  [(Dutch, 1), (computer, 1), (scientist, 1), ((...
# 2                 1                                        [(None, 1)]
# 3                 1  [(Israeli, 1), (American, 1), (computer, 1), (...
# 4                 1  [(American, 1), (computer, 1), (scientist, 1),...
# 5                 1                                        [(None, 1)]
# 6                 1  [(American, 1), (logician, 1), ((, 1), (born, ...
# 7                 1                                        [(None, 1)]
# 8                 1  [(British, 1), (computer, 1), (scientist, 1), ...
# 9                 1                                        [(None, 1)]
#
#                     common_words_after_preprocessing
# 0  [english, computer, scientist, inventor, world...
# 1            [dutch, computer, scientist, 1930–2002]
# 2                                             [none]
# 3           [israeli, american, computer, scientist]
# 4  [american, computer, scientist, mathematician,...
# 5                                             [none]
# 6                   [american, logician, born, 1932]
# 7                                             [none]
# 8          [british, computer, scientist, 1913–2010]
# 9                                             [none]

# %% [markdown]
# ## 3.2 Sub-activity: Applying NLP operations on the corpus

# %% [markdown]
# ### Task 6

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

intro_words = df['intro'].tolist()  # create list of all intros
stopwords_set = set(stopwords.words('english'))  # stopwords
porter_stemmer = PorterStemmer()  # create PorterStemmer instance

def preprocess_intro(text):  # function to preprocess text
    words = word_tokenize(str(text))
    filtered_words = []
    for word in words: #iterate through each word
        lowercase_word = word.lower() # make lower
        if lowercase_word not in stopwords_set and lowercase_word not in string.punctuation: # if not in stop words or punctuation, add to filtered words list
            filtered_words.append(lowercase_word)
    return filtered_words # preprocessing (part (a))

preprocessed_intro_words = []
for intro in intro_words:  # apply pre processing to each word in intro
    processed_intro = preprocess_intro(intro)
    if processed_intro != ['none']: # get rid of 'none' values (issue with how long my intros are)
        preprocessed_intro_words.append(processed_intro)

all_words = []
for sublist in preprocessed_intro_words: # loop to get every word in dict in to one list
    if isinstance(sublist, list): # if list within list
        for word in sublist:
            all_words.append(word) # append to list

unique_words_count = len(set(all_words)) # get each unique word (set)
print(f"Number of unique words before stemming: {unique_words_count}") # part (b)

stemmed_intro_words = [] # declare list for stemmed words
for word in all_words: # iterate through each word
    stemmed_word = porter_stemmer.stem(word) # apply porter stemmer
    stemmed_intro_words.append(stemmed_word) # append to list
    
unique_stemmed_words_count = len(set(stemmed_intro_words)) # get each unique word (set)
print(f"Number of unique words after stemming: {unique_stemmed_words_count}") # part (c)
# Again the results being the same may be an issue with the intro I'm getting from the wikipedia API.
# Out:
# Number of unique words before stemming: 47
# Number of unique words after stemming: 47

# %% [markdown]
# ### Task 7

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import string

intro_words = df['intro'].tolist()  # create list of all intros
stopwords_set = set(stopwords.words('english'))  # stopwords

def preprocess_intro(text):  # function to preprocess text
    words = word_tokenize(str(text))
    filtered_words = []
    for word in words: #iterate through each word
        lowercase_word = word.lower() # make lower
        if lowercase_word not in stopwords_set and lowercase_word not in string.punctuation: # if not in stop words or punctuation, add to filtered words list
            filtered_words.append(lowercase_word)
    return filtered_words # part (a)

preprocessed_intro_words = []
for intro in intro_words:  # apply pre processing to each word in intro
    processed_intro = preprocess_intro(intro)
    if processed_intro != ['none']: # get rid of 'none' values (issue with how long my intros are)
        preprocessed_intro_words.append(processed_intro)

all_words = []
for sublist in preprocessed_intro_words: # loop to get every word in dict in to one list
    if isinstance(sublist, list): # if list within list
        for word in sublist:
            all_words.append(word) # append to list

unique_words_count = len(set(all_words)) # get unique words again
print(f"Number of unique words before stemming: {unique_words_count}") # part (b)

snowball_stemmer = SnowballStemmer("english") # get snowball stemmer
stemmed_intro_words_snowball = [] # create list of stemmed intro words
for word in all_words:
    stemmed_word = snowball_stemmer.stem(word) # stem
    stemmed_intro_words_snowball.append(stemmed_word) # add to list

unique_stemmed_words_count_snowball = len(set(stemmed_intro_words_snowball)) # get unique words
print(f"Number of unique words after stemming with SnowballStemmer: {unique_stemmed_words_count_snowball}") #part (c)
# Out:
# Number of unique words before stemming: 47
# Number of unique words after stemming with SnowballStemmer: 47

# %% [markdown]
# ### Task 8

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet') # uncomment if wordnet needs downloading
import string

intro_words = df['intro'].tolist()  # create list of all intros
stopwords_set = set(stopwords.words('english'))  # stopwords
lemmatizer = WordNetLemmatizer()  # create WordNetLemmatizer instance

def preprocess_intro(text):  # function to preprocess text
    words = word_tokenize(str(text))
    filtered_words = []
    for word in words: #iterate through each word
        lowercase_word = word.lower() # make lower
        if lowercase_word not in stopwords_set and lowercase_word not in string.punctuation: # if not in stop words or punctuation, add to filtered words list
            filtered_words.append(lowercase_word)
    return filtered_words # part (a)

preprocessed_intro_words = []
for intro in intro_words:  # apply pre processing to each word in intro
    processed_intro = preprocess_intro(intro)
    if processed_intro != ['none']: # get rid of 'none' values (issue with how long my intros are)
        preprocessed_intro_words.append(processed_intro)

all_words = []
for sublist in preprocessed_intro_words: # loop to get every word in dict in to one list
    if isinstance(sublist, list): # if list within list
        for word in sublist:
            all_words.append(word) # append to list

unique_words_count = len(set(all_words))
print(f"Number of unique words before lemmatization: {unique_words_count}") # part (b)

lemmatized_intro_words = []
for word in all_words: # iterate through each word
    lemmatized_word = lemmatizer.lemmatize(word) # use lemmatizer
    lemmatized_intro_words.append(lemmatized_word)
unique_lemmatized_words_count = len(set(lemmatized_intro_words)) # get unique words (set)
print(f"Number of unique words after lemmatization: {unique_lemmatized_words_count}") # part (c)
# Out:
# Number of unique words before lemmatization: 47
# Number of unique words after lemmatization: 47

# %%
# This was as far as I managed to get for this activity.
